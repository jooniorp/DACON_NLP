# %% [markdown]
# # KorEDA

# %% [markdown]
# ## Load Library

# %%
import random
import pickle
import re

# %% [markdown]
# ## Load WordNet

# %%
with open("wordnet.pickle", "rb") as f:
    wordnet = pickle.load(f)

# %%
wordnet
# Out:
# {'호흡하': ['호흡하'],
#  '물': ['물', '놈'],
#  '질식하': ['질식하'],
#  '전체': ['전체', '전적', '전부', '총체', '전반'],
#  '한숨짓': ['한숨짓'],
#  '생물': ['생물'],
#  '미생물': ['미생물', '생물'],
#  '헐떡이': ['헐떡이'],
#  '셀': ['셀', '세포'],
#  '하품하': ['하품하'],
#  '인': ['인', '인간', '인물', '사람', '인류'],
#  '미물': ['미물', '생물', '조수'],
#  '기상하': ['기상하'],
#  '자연물': ['자연물'],
#  '영양': ['영양', '자양', '영양분', '양분', '영양소'],
#  '물건': ['물건', '기품', '물', '물품', '물체', '놈'],
#  '학식': ['학식', '학문', '인식', '알음알이', '인지', '지식', '경험', '식견'],
#  '속성': ['속성'],
#  '긴장하': ['긴장하'],
#  '감정': ['감정', '마음', '기분'],
#  '유형': ['유형',
#   '폼',
#   '형상',
#   '체형',
#   '형',
#   '자세',
#   '맵시',
#   '형태',
#   '형용',
#   '복장',
#   '꼴',
#   '거푸집',
#   '모양',
#   '짝',
#   '형체',
#   '용모',
#   '외형',
#   '모양새',
#   '모형'],
#  '시간': ['시간', '성상', '세월'],
#  '길': ['길', '과정', '경로'],
#  '짓': ['짓', '법', '소위', '행위'],
#  '집단': ['집단', '무리', '군', '통'],
#  '상관': ['상관', '연고', '관계', '인연', '사이', '동안', '연관', '관련'],
#  '재': ['재', '소장', '것', '점령', '소유물', '손', '소유', '향유', '점유', '재물'],
#  '커뮤니케이션': ['커뮤니케이션', '교신', '통신'],
#  '수량': ['수량', '정량', '양', '분량', '숱'],
#  '속임질하': ['속임질하'],
#  '중단': ['중단'],
#  '목욕하': ['목욕하'],
#  '사적': ['사적', '공적', '위업', '공', '공로', '업적'],
#  '명예': ['명예'],
#  '상환': ['상환', '교류', '교역', '교환'],
#  '거래': ['거래'],
#  '출현': ['출현'],
#  '줄행랑': ['줄행랑'],
#  '작위': ['작위'],
#  '성적': ['성적'],
#  '도래': ['도래', '도달', '내도', '당도', '도착'],
#  '귀착': ['귀착'],
#  '착륙': ['착륙', '착지'],
#  '결별': ['결별', '일별', '사별', '작별', '고별'],
#  '고별': ['고별'],
#  '소산': ['소산', '소실'],
#  '이민': ['이민'],
#  '퇴축': ['퇴축', '후퇴', '뒷걸음질'],
#  '도망': ['도망'],
#  '패주': ['패주', '도주', '도망', '일주', '줄행랑', '탈출'],
#  '법': ['법'],
#  '탈옥': ['탈옥'],
#  '종결': ['종결', '완결'],
#  '기록': ['기록', '등록'],
#  '부화하': ['부화하'],
#  '성공': ['성공', '성사'],
#  '대성공': ['대성공'],
#  '정복': ['정복', '제패', '퇴치', '극복'],
#  '합격': ['합격', '통과', '패스', '급제'],
#  '실패': ['실패', '파탄'],
#  '결석': ['결석'],
#  '분실': ['분실', '실추', '소실', '패배', '상실'],
#  '실추': ['실추', '항복', '투항'],
#  '퇴보': ['퇴보', '실패'],
#  '위반': ['위반'],
#  '분비하': ['분비하'],
#  '실책': ['실책'],
#  '배설하': ['배설하', '배출하'],
#  '배출하': ['배출하'],
#  '변통하': ['변통하'],
#  '바보짓': ['바보짓'],
#  '결례': ['결례', '실례'],
#  '엉덩방아': ['엉덩방아'],
#  '습득': ['습득', '취득', '획득', '포착'],
#  '매수': ['매수', '취득', '구입'],
#  '환수': ['환수'],
#  '구입': ['구입'],
#  '고치': ['고치', '치유하', '치료하'],
#  '계승': ['계승', '상속', '인계'],
#  '전승': ['전승', '유전'],
#  '취득': ['취득', '구입', '획득'],
#  '차용': ['차용', '차입'],
#  '재정': ['재정'],
#  '제패': ['제패', '정복', '진압', '퇴치', '극복'],
#  '사수': ['사수', '수령', '영수', '수납', '수취', '감수', '접수', '입수', '수용', '수수'],
#  '공매': ['공매', '경매'],
#  '밀매': ['밀매'],
#  '원대복귀하': ['원대복귀하'],
#  '구난': ['구난', '구호', '구급', '구조', '구원', '구제', '구출'],
#  '구명': ['구명'],
#  '구원': ['구원', '제도', '구령', '구조', '구제'],
#  '발아하': ['발아하', '싹트'],
#  '해제': ['해제', '해방'],
#  '개발': ['개발'],
#  '제도': ['제도', '구제', '구령', '구원'],
#  '집행': ['집행', '달성', '시행', '작위', '실시', '실행', '수행', '이행', '단행'],
#  '힘': ['힘', '활동', '시중', '도움', '용역'],
#  '행사하': ['행사하', '사역하', '세공하'],
#  '상영': ['상영'],
#  '던지기': ['던지기'],
#  '투하': ['투하', '던지기'],
#  '밀': ['밀'],
#  '추상': ['추상'],
#  '견인': ['견인', '끌'],
#  '구토': ['구토'],
#  '전달': ['전달'],
#  '전기': ['전기'],
#  '결투': ['결투', '전투'],
#  '접촉': ['접촉', '교접', '터치', '상접'],
#  '마찰': ['마찰'],
#  '충돌': ['충돌'],
#  '조작': ['조작'],
#  '호환하': ['호환하', '상환하', '교환하', '교체하'],
#  '감사': ['감사'],
#  '검시': ['검시'],
#  '조사': ['조사'],
#  '조합': ['조합', '비교', '대비'],
#  '연쇄': ['연쇄', '반연', '접속', '연결', '결선', '접합'],
#  '교차': ['교차'],
#  '접근': ['접근', '근접'],
#  '접합': ['접합', '연쇄', '연결', '접속'],
#  '접속': ['접속', '연결', '접합'],
#  '연결': ['연결'],
#  '측정': ['측정'],
#  '다가오': ['다가오'],
#  '해결': ['해결'],
#  '커지': ['커지', '확장하', '확대하'],
#  '등반하': ['등반하', '등산하', '오르'],
#  '사주': ['사주', '선동', '교사'],
#  '증가하': ['증가하', '증폭하'],
#  '노출': ['노출'],
#  '위법행위': ['위법행위'],
#  '선': ['선', '옵션', '선발', '취사', '발탁', '고르', '간발', '선별', '발췌', '선택', '엄선'],
#  '발췌': ['발췌'],
#  '결정': ['결정', '재정', '결론', '정량', '재결', '완결', '결의', '확정', '내리'],
#  '전환': ['전환'],
#  '기용': ['기용', '채용', '선임', '임용', '보직', '임명', '등용'],
#  '선임': ['선임', '임명'],
#  '분담': ['분담', '분부', '할당', '배분', '배당', '배정'],
#  '분부': ['분부', '분배', '할당', '배분', '배부', '배당', '배정'],
#  '조치': ['조치', '조작', '법'],
#  '이사': ['이사', '이전', '전출'],
#  '책략': ['책략', '계', '술수', '모함', '술책', '계책', '모략', '기도', '계략', '음모'],
#  '방도': ['방도', '방법', '도리', '길', '수단', '투', '모양', '법', '수법'],
#  '철수하': ['철수하', '삭제하', '철거하', '제거하', '공제하', '배제하', '제외하'],
#  '제거하': ['제거하'],
#  '첩경': ['첩경', '술', '방편', '수단', '방도', '편법'],
#  '소거하': ['소거하'],
#  '제외하': ['제외하'],
#  '추첨': ['추첨'],
#  '결의': ['결의', '작심', '결심', '결단', '각오'],
#  '동의': ['동의'],
#  '선출': ['선출', '선택'],
#  '재선': ['재선', '재선거'],
#  '선거': ['선거'],
#  '부가하': ['부가하', '첨가하', '가미하'],
#  '총선': ['총선', '총선거'],
#  '예비선거': ['예비선거'],
#  '보선': ['보선', '선거'],
#  '대체': ['대체', '변환', '전환'],
#  '절약': ['절약', '경제'],
#  '조정': ['조정', '조절'],
#  '벗기': ['벗기'],
#  '치환': ['치환'],
#  '간섭': ['간섭', '참견', '개입'],
#  '금제': ['금제', '금물', '금지', '제지'],
#  '저항': ['저항', '항전', '대립', '반발', '반항', '거역', '대항'],
#  '반발': ['반발'],
#  '거부': ['거부', '사절', '각하', '퇴각', '거절', '퇴짜'],
#  '거절': ['거절'],
#  '손가락질': ['손가락질'],
#  '사절': ['사절'],
#  '타락하': ['타락하'],
#  '변절': ['변절'],
#  '체념': ['체념'],
#  '배타': ['배타'],
#  '해임': ['해임'],
#  '마감': ['마감', '종국', '종결', '결말', '종료', '종지', '완료', '완결', '만료', '귀착', '끝', '귀결'],
#  '종국': ['종국', '종결'],
#  '완결': ['완결'],
#  '졸업': ['졸업'],
#  '양도': ['양도', '양여'],
#  '양여': ['양여'],
#  '제외': ['제외', '면제', '면역'],
#  '면직': ['면직'],
#  '사멸': ['사멸', '멸망', '파멸'],
#  '망치': ['망치', '멸망', '패망', '파멸'],
#  '태우': ['태우'],
#  '말리': ['말리', '건조하', '마르'],
#  '분쇄': ['분쇄'],
#  '살인': ['살인', '타살'],
#  '학살': ['학살', '살해', '실행', '타살', '살인'],
#  '암살': ['암살'],
#  '살상': ['살상'],
#  '자결': ['자결', '자해', '자인', '자살'],
#  '자멸': ['자멸'],
#  '자살': ['자살'],
#  '희석하': ['희석하'],
#  '압축': ['압축'],
#  '철폐': ['철폐', '폐지'],
#  '결말': ['결말'],
#  '종료': ['종료', '폐점', '중단', '마감', '폐장'],
#  '소화': ['소화'],
#  '전개하': ['전개하'],
#  '지배하': ['지배하'],
#  '정착': ['정착', '대', '확립', '수립', '결성', '성립', '조성', '건설', '편성', '편제', '형성'],
#  '농축하': ['농축하'],
#  '감응': ['감응'],
#  '기공식': ['기공식'],
#  '개설': ['개설', '발족', '시동', '창업', '개시'],
#  '감축하': ['감축하', '감량하', '축소하'],
#  '대': ['대'],
#  '시설': ['시설', '장치', '설치', '설비'],
#  '축소하': ['축소하'],
#  '기동': ['기동'],
#  '자르': ['자르'],
#  '동자': ['동자', '요리', '조리', '취사'],
#  '퇴보하': ['퇴보하'],
#  '여물': ['여물'],
#  '발전': ['발전', '진보'],
#  '대청소': ['대청소', '청소'],
#  '걸레질': ['걸레질'],
#  '유래하': ['유래하'],
#  '청소': ['청소'],
#  '목욕': ['목욕'],
#  '대신': ['대신', '반상', '보답', '유상', '보수', '대상'],
#  '대상': ['대상'],
#  '유신': ['유신', '개선', '혁신', '변혁', '개량', '개혁', '쇄신', '경신'],
#  '장식': ['장식'],
#  '수장': ['수장', '겉치레', '장식'],
#  '교화': ['교화'],
#  '수선': ['수선', '고치', '개수', '수복', '수리', '보수'],
#  '보수': ['보수'],
#  '수복': ['수복'],
#  '배포하': ['배포하'],
#  '재생': ['재생'],
#  '부패': ['부패', '퇴폐', '타락', '위법행위'],
#  '백화': ['백화'],
#  '변색': ['변색', '퇴색', '탈색'],
#  '배열하': ['배열하'],
#  '오염': ['오염'],
#  '조작하': ['조작하'],
#  '이동': ['이동', '운동'],
#  '이력': ['이력'],
#  '보행': ['보행'],
#  '산보': ['산보', '산책'],
#  '산책': ['산책'],
#  '마술': ['마술'],
#  '배회': ['배회', '암행'],
#  '단축하': ['단축하', '생략하'],
#  '주파': ['주파', '달리', '주행', '러닝'],
#  '질주': ['질주', '대시'],
#  '기': ['기'],
#  '유망': ['유망', '유랑', '방랑', '유전', '유리'],
#  '표류': ['표류'],
#  '유도': ['유도', '운전'],
#  '비행': ['비행', '항공'],
#  '취항': ['취항'],
#  '여행': ['여행'],
#  '분화하': ['분화하'],
#  '사파리': ['사파리'],
#  '행락': ['행락'],
#  '주행': ['주행'],
#  '변환': ['변환'],
#  '재평가하': ['재평가하'],
#  '교통': ['교통', '전역', '전환', '운수', '전이', '전진', '이동', '대체', '이전'],
#  '사업': ['사업'],
#  '운반': ['운반'],
#  '신장하': ['신장하'],
#  '이입': ['이입'],
#  '포장': ['포장', '꾸리'],
#  '상행': ['상행', '상승', '승천'],
#  '급상승': ['급상승'],
#  '강하': ['강하'],
#  '하락': ['하락', '저하', '강하'],
#  '복귀': ['복귀', '대신'],
#  '흐름': ['흐름', '유동'],
#  '방류': ['방류'],
#  '분류': ['분류'],
#  '운신': ['운신'],
#  '분할하': ['분할하', '칸막이하', '가름하'],
#  '태도': ['태도', '제스처', '몸짓', '법'],
#  '파괴하': ['파괴하', '훼손하', '균열하'],
#  '파손하': ['파손하', '파괴하', '균열하'],
#  '폭파하': ['폭파하'],
#  '자전': ['자전', '선전', '회전'],
#  '실추하': ['실추하', '떨어지'],
#  '소용돌이': ['소용돌이', '회전'],
#  '선전': ['선전', '회전'],
#  '회전': ['회전'],
#  '경시하': ['경시하', '착수하', '시작하', '스타트하'],
#  '유턴': ['유턴'],
#  '들어가': ['들어가'],
#  '착수하': ['착수하'],
#  '서': ['서'],
#  '우회전': ['우회전'],
#  '할인': ['할인'],
#  '삭감': ['삭감'],
#  '소비': ['소비', '소모'],
#  '분리': ['분리', '절단'],
#  '이발': ['이발'],
#  '수축': ['수축'],
#  '출생하': ['출생하', '탄생하'],
#  '희석': ['희석'],
#  '증대': ['증대', '증액', '증가', '증식', '증강', '증진', '팽창', '번식'],
#  '첨가': ['첨가', '플러스', '증가', '치환', '추가', '부가'],
#  '증진': ['증진', '증가'],
#  '감가': ['감가'],
#  '급증': ['급증'],
#  '증폭': ['증폭'],
#  '승화하': ['승화하'],
#  '확장': ['확장', '팽창', '확대'],
#  '팽창': ['팽창', '확장'],
#  '신축': ['신축'],
#  '전개': ['전개', '확장', '부식'],
#  '가제': ['가제', '증폭'],
#  '주석': ['주석', '주'],
#  '저장': ['저장', '축적', '장치', '비축'],
#  '포용': ['포용', '포함', '내포'],
#  '증강': ['증강'],
#  '농축': ['농축'],
#  '파손': ['파손', '분쇄', '파괴', '타파', '파열', '균열', '훼손', '손상'],
#  '파열': ['파열', '파괴'],
#  '균열': ['균열', '파손', '파괴'],
#  '연소하': ['연소하', '사르'],
#  '소실하': ['소실하', '소진하'],
#  '소각하': ['소각하', '사르', '연소하'],
#  '발화': ['발화', '점화'],
#  '부착': ['부착', '첨부', '흡착'],
#  '교환하': ['교환하', '교체하', '바꾸'],
#  '통일': ['통일'],
#  '분구': ['분구', '가름', '분리', '유리'],
#  '이탈': ['이탈'],
#  '분할': ['분할'],
#  '양분': ['양분', '이분'],
#  '가름': ['가름'],
#  '해리': ['해리'],
#  '분단': ['분단', '분할', '세분'],
#  '지분': ['지분', '분파', '분기'],
#  '분기': ['분기'],
#  '절제': ['절제'],
#  '제거': ['제거'],
#  '소거': ['소거', '제거', '삭제'],
#  '삭제': ['삭제', '제거', '소거', '배제', '도태', '해독'],
#  '철거': ['철거', '철수'],
#  '소수': ['소수', '탈수'],
#  '거세': ['거세', '삭제'],
#  '세분': ['세분'],
#  '분산하': ['분산하'],
#  '마련하': ['마련하', '대비하', '준비하'],
#  '활동': ['활동', '활약', '움직임'],
#  '체험': ['체험', '실천'],
#  '발전하': ['발전하', '전개하'],
#  '협동': ['협동', '제휴', '협력', '협조', '공동'],
#  '관습': ['관습', '버릇'],
#  '의식': ['의식'],
#  '투': ['투', '방식'],
#  '고정하': ['고정하'],
#  '정상화하': ['정상화하'],
#  '무시': ['무시', '도외시'],
#  '핍박': ['핍박', '박해'],
#  '박해': ['박해'],
#  '결실시키': ['결실시키'],
#  '나타나': ['나타나', '출현하'],
#  '운동': ['운동'],
#  '행하': ['행하', '축제', '축전'],
#  '무용': ['무용', '춤', '댄스', '무도'],
#  '오락': ['오락'],
#  '해학': ['해학'],
#  '도박': ['도박', '노름', '하', '장난'],
#  '게임': ['게임', '유희'],
#  '하': ['하'],
#  '곡예': ['곡예'],
#  '경영': ['경영', '경주', '주행', '달리기', '러닝'],
#  '높이뛰기': ['높이뛰기'],
#  '스키': ['스키'],
#  '수영': ['수영', '헤엄'],
#  '기화하': ['기화하'],
#  '다이빙': ['다이빙'],
#  '권투': ['권투', '복싱'],
#  '시합': ['시합', '매치'],
#  '양궁': ['양궁'],
#  '레슬링': ['레슬링', '씨름'],
#  '스모': ['스모', '씨름'],
#  '스케이트': ['스케이트', '스케이팅'],
#  '경주': ['경주', '레이스', '러닝', '경마', '달리기'],
#  '경마': ['경마'],
#  '투우': ['투우'],
#  '사냥': ['사냥', '수렵'],
#  '달리기': ['달리기'],
#  '농사': ['농사', '영농', '농경', '농업', '경작', '농'],
#  '보충하': ['보충하'],
#  '낚시': ['낚시'],
#  '어로': ['어로', '어업', '고기잡이'],
#  '공격': ['공격'],
#  '볼링': ['볼링'],
#  '몸': ['몸'],
#  '하키': ['하키'],
#  '수구': ['수구'],
#  '골프': ['골프'],
#  '약': ['약'],
#  '풋볼': ['풋볼', '축구'],
#  '야구': ['야구', '구기'],
#  '절제하': ['절제하'],
#  '연마하': ['연마하'],
#  '삭제하': ['삭제하', '제거하', '불식하'],
#  '송구': ['송구', '핸드볼'],
#  '배구': ['배구'],
#  '정구': ['정구', '테니스'],
#  '측정하': ['측정하'],
#  '포커': ['포커'],
#  '분리하': ['분리하'],
#  '당구': ['당구'],
#  '장기': ['장기'],
#  '바둑': ['바둑'],
#  '해독하': ['해독하'],
#  '노름': ['노름'],
#  '도': ['도'],
#  '카니발': ['카니발'],
#  '불장난': ['불장난'],
#  '강조하': ['강조하'],
#  '잔치': ['잔치', '축제', '축전'],
#  '충전하': ['충전하'],
#  '축제': ['축제'],
#  '행세': ['행세'],
#  '훼방하': ['훼방하', '방해하'],
#  '스포츠': ['스포츠', '체육', '운동'],
#  '발레': ['발레'],
#  '댄스': ['댄스'],
#  '원무': ['원무'],
#  '개시하': ['개시하'],
#  '확충하': ['확충하', '확장하', '확대하'],
#  '음악': ['음악', '음률'],
#  '종': ['종'],
#  '양식': ['양식', '법'],
#  '행위': ['행위'],
#  '상연': ['상연', '작위'],
#  '자극': ['자극'],
#  '저해': ['저해', '지장', '훼방', '방해'],
#  '장애': ['장애', '막'],
#  '훼방': ['훼방', '방해'],
#  '타격': ['타격', '타구'],
#  '연결하': ['연결하'],
#  '훅': ['훅'],
#  '어프로치': ['어프로치'],
#  '일하': ['일하', '소위'],
#  '언행': ['언행'],
#  '빨래': ['빨래', '세탁'],
#  '용역': ['용역'],
#  '세대': ['세대', '안일', '가사'],
#  '영업': ['영업', '일'],
#  '직업': ['직업', '아르바이트', '노릇', '일자리', '세공', '조업', '일', '일하', '소위', '업'],
#  '임무': ['임무', '직책', '직분'],
#  '근무': ['근무', '활동', '복무', '용역'],
#  '납득하': ['납득하', '파악하', '이해하', '터득하', '포착하', '양해하'],
#  '이해하': ['이해하', '양해하'],
#  '포착하': ['포착하', '납득하', '터득하', '파악하'],
#  '가지': ['가지'],
#  '소화하': ['소화하'],
#  '양해하': ['양해하', '이해하'],
#  '소위': ['소위'],
#  '학습하': ['학습하', '습득하', '수습하', '수학하', '배우'],
#  '채용하': ['채용하', '채택하'],
#  '교육하': ['교육하'],
#  '레슨하': ['레슨하', '연마하', '훈련하', '체험하', '수련하', '연습하'],
#  '가업': ['가업', '영업', '기능', '일'],
#  '추상같': ['추상같'],
#  '석공': ['석공'],
#  '조종': ['조종'],
#  '기억하': ['기억하'],
#  '상기하': ['상기하', '생각하'],
#  '정치': ['정치'],
#  '떠나': ['떠나'],
#  '쓰기': ['쓰기', '기록', '집필', '표기', '휘호', '글짓기'],
#  '망각하': ['망각하'],
#  '표기': ['표기'],
#  '상기': ['상기'],
#  '서명': ['서명'],
#  '재봉': ['재봉'],
#  '곡해하': ['곡해하', '오해하'],
#  '노역': ['노역'],
#  '근로': ['근로', '노력', '노고', '진력'],
#  '노력': ['노력', '신고', '일', '수고'],
#  '오해하': ['오해하'],
#  '턱걸이': ['턱걸이'],
#  '의술': ['의술', '의사'],
#  '상정하': ['상정하', '추정하', '간주하', '가정하', '가설하'],
#  '근면': ['근면', '정진'],
#  '예견하': ['예견하', '예상하', '상정하', '추정하', '추상같', '간주하', '가정하', '가설하'],
#  '사찰': ['사찰', '취조', '심사', '탐사', '조사', '수사'],
#  '가동하': ['가동하'],
#  '수사': ['수사'],
#  '검거': ['검거'],
#  '취조': ['취조', '신문', '검찰', '심사', '정사', '심리', '검문', '조사', '전의'],
#  '심리': ['심리', '조사', '취조'],
#  '경험': ['경험'],
#  '시험': ['시험', '테스트', '시도'],
#  '전형': ['전형', '심사'],
#  '연구하': ['연구하', '취조하', '탐구하', '수사하', '조사하'],
#  '판별하': ['판별하', '식별하'],
#  '유비': ['유비'],
#  '대비': ['대비'],
#  '대조': ['대조', '비교', '대비'],
#  '비교하': ['비교하'],
#  '분류하': ['분류하'],
#  '치료': ['치료'],
#  '의료': ['의료', '진료'],
#  '채점하': ['채점하'],
#  '평정하': ['평정하'],
#  '평가하': ['평가하', '평정하'],
#  '대비하': ['대비하', '대조하'],
#  '조합하': ['조합하'],
#  '일사': ['일사'],
#  '검열하': ['검열하', '검사하', '점검하'],
#  '투약': ['투약'],
#  '입증하': ['입증하', '논증하', '실증하', '증명하', '뒷받침하'],
#  '간병': ['간병', '구완', '구호', '병구완', '구원', '간호'],
#  '증명하': ['증명하'],
#  '반증하': ['반증하'],
#  '승낙하': ['승낙하', '승복하', '수용하'],
#  '판정하': ['판정하'],
#  '선정하': ['선정하'],
#  '선출하': ['선출하'],
#  '예정하': ['예정하', '일정하'],
#  '사정하': ['사정하', '평가하', '평정하', '감정하'],
#  '지지': ['지지'],
#  '간주하': ['간주하'],
#  '거부하': ['거부하', '거절하'],
#  '부인하': ['부인하'],
#  '호의호식하': ['호의호식하', '회의하', '반신반의하', '의아하', '의심하'],
#  '평판하': ['평판하', '간주하'],
#  '존중하': ['존중하'],
#  '재판': ['재판'],
#  '관리': ['관리'],
#  '과대평가하': ['과대평가하'],
#  '관장': ['관장'],
#  '추억하': ['추억하', '회고하', '생각하'],
#  '사열하': ['사열하', '재검토하', '검토하', '검사하'],
#  '드레싱': ['드레싱'],
#  '주사': ['주사'],
#  '결정하': ['결정하', '결의하'],
#  '결심하': ['결심하', '결정하', '작심하', '결단하', '결의하'],
#  '회복': ['회복'],
#  '기도하': ['기도하', '도모하', '기획하', '계획하', '설계하'],
#  '기획하': ['기획하', '설계하', '도모하', '기도하', '계획하', '예정하'],
#  '희망하': ['희망하', '촉망하'],
#  '제안하': ['제안하', '제창하'],
#  '제의하': ['제의하', '제안하'],
#  '계획하': ['계획하'],
#  '소독': ['소독', '살균'],
#  '입안하': ['입안하', '도모하', '계획하', '설계하'],
#  '대증': ['대증'],
#  '설계하': ['설계하'],
#  '탑재': ['탑재', '적재'],
#  '채취': ['채취'],
#  '토론하': ['토론하', '토의하', '논의하'],
#  '공작': ['공작'],
#  '규정하': ['규정하'],
#  '가설하': ['가설하', '가정하'],
#  '가정하': ['가정하'],
#  '도포': ['도포', '칠', '페인트칠', '도장'],
#  '예기하': ['예기하', '예상하'],
#  '기다리': ['기다리'],
#  '예지하': ['예지하', '예기하', '예견하', '예상하'],
#  '신임하': ['신임하'],
#  '집중하': ['집중하'],
#  '개의하': ['개의하', '마음먹'],
#  '스틸': ['스틸'],
#  '만들': ['만들'],
#  '실행': ['실행', '악행'],
#  '불법행위': ['불법행위'],
#  '죄': ['죄', '악행'],
#  '반칙': ['반칙'],
#  '지불하': ['지불하'],
#  '지정하': ['지정하'],
#  '도피': ['도피', '회피'],
#  '회피': ['회피'],
#  '허비': ['허비', '탕진', '낭비'],
#  '위배': ['위배', '반칙', '위반', '죄', '악업', '악행'],
#  '부정': ['부정', '악사', '악행'],
#  '악사': ['악사'],
#  '장난': ['장난'],
#  '유언하': ['유언하'],
#  '말하': ['말하'],
#  '호령하': ['호령하', '명령하', '지령하', '지시하'],
#  '대역': ['대역'],
#  '교시하': ['교시하'],
#  '촉탁하': ['촉탁하'],
#  '너스레': ['너스레'],
#  '명령하': ['명령하', '지시하'],
#  '가짜': ['가짜'],
#  '요청하': ['요청하', '부탁하', '의뢰하', '청하'],
#  '사기': ['사기'],
#  '요구하': ['요구하', '청구하'],
#  '원죄': ['원죄', '부정', '책임', '죄', '죄과', '죄업'],
#  '대죄': ['대죄', '책임', '원죄', '죄', '죄업'],
#  '거만': ['거만'],
#  '선망': ['선망', '질투', '시기'],
#  '태만': ['태만'],
#  '음행': ['음행'],
#  '염불하': ['염불하', '기도하'],
#  '상종하': ['상종하'],
#  '선언하': ['선언하', '공언하'],
#  '중재하': ['중재하', '조정하'],
#  '화해하': ['화해하'],
#  '악행': ['악행'],
#  '신청하': ['신청하'],
#  '설득하': ['설득하'],
#  '죄악': ['죄악'],
#  '구타': ['구타', '협박', '폭행'],
#  '납치': ['납치'],
#  '유린': ['유린', '침해'],
#  '장려하': ['장려하', '고취하', '권장하', '격려하', '고무하', '독려하'],
#  '위증죄': ['위증죄'],
#  '나타내': ['나타내'],
#  '폭행': ['폭행'],
#  '반대하': ['반대하'],
#  '절도죄': ['절도죄', '도둑질'],
#  '전범': ['전범'],
#  '질문하': ['질문하', '문의하'],
#  '협박': ['협박'],
#  '질의하': ['질의하'],
#  '문초하': ['문초하', '사문화하', '심문하', '신문하'],
#  '반문하': ['반문하'],
#  '공헌': ['공헌', '기여', '하'],
#  '해방': ['해방'],
#  '신고': ['신고', '노력', '노고', '수고'],
#  '전화하': ['전화하', '통화하'],
#  '탈취': ['탈취'],
#  '실험': ['실험', '시험', '시행', '테스트', '시도'],
#  '오디션': ['오디션'],
#  '금하': ['금하', '금지하'],
#  '사행': ['사행'],
#  '금지하': ['금지하'],
#  '거절하': ['거절하'],
#  '교전': ['교전', '전쟁', '전투'],
#  '자조': ['자조'],
#  '허용하': ['허용하', '허락하'],
#  '허락하': ['허락하', '허가하'],
#  '통과하': ['통과하'],
#  '통제': ['통제', '규제', '제어', '단속'],
#  '제약': ['제약', '속박', '규제', '제한', '구속', '질곡'],
#  '억제': ['억제'],
#  '동결': ['동결'],
#  '면담하': ['면담하'],
#  '탄압': ['탄압', '단속'],
#  '점령': ['점령', '소유', '점유', '향유', '손'],
#  '보유': ['보유', '간수', '포유', '보지', '보관'],
#  '간수': ['간수', '보관'],
#  '상담하': ['상담하', '이야기하', '담화하'],
#  '말대꾸하': ['말대꾸하'],
#  '부정하': ['부정하', '부인하'],
#  '자인하': ['자인하', '승인하', '긍정하', '시인하'],
#  '보위': ['보위', '수호', '옹호', '양호', '보호', '비호'],
#  '자백하': ['자백하'],
#  '고백하': ['고백하', '자백하'],
#  '보장': ['보장', '보위', '보지', '보존', '보호', '유지', '보전', '보수'],
#  '보지': ['보지', '보존', '보호', '유지', '보전', '보수'],
#  '보존': ['보존'],
#  '호신': ['호신', '보신'],
#  '유보': ['유보'],
#  '심판하': ['심판하'],
#  '농담하': ['농담하'],
#  '경호': ['경호', '경위', '순찰', '순경', '순시'],
#  '비난하': ['비난하', '힐난하'],
#  '비평하': ['비평하'],
#  '호위': ['호위'],
#  '교화하': ['교화하'],
#  '보호': ['보호'],
#  '가르치': ['가르치'],
#  '입': ['입', '패용'],
#  '호흡': ['호흡', '숨결', '숨'],
#  '날숨': ['날숨', '숨'],
#  '불': ['불'],
#  '들숨': ['들숨'],
#  '숨': ['숨'],
#  '음식': ['음식'],
#  '눈속임하': ['눈속임하'],
#  '초식': ['초식', '채식'],
#  '과식': ['과식'],
#  '시식': ['시식'],
#  '생식': ['생식'],
#  '두말하': ['두말하'],
#  '규탄하': ['규탄하'],
#  '논란하': ['논란하', '지탄하'],
#  '성': ['성', '성교', '씹', '방사'],
#  '탄핵하': ['탄핵하'],
#  '악담하': ['악담하'],
#  '교미': ['교미', '육교', '방사', '씹', '관계', '성교', '상관', '성행위'],
#  '성교': ['성교'],
#  '무고하': ['무고하'],
#  '간음': ['간음'],
#  '상피': ['상피'],
#  '남색': ['남색'],
#  '선동하': ['선동하'],
#  '포옹': ['포옹'],
#  '기만하': ['기만하'],
#  '지음': ['지음'],
#  '자위': ['자위'],
#  '칭찬하': ['칭찬하', '예찬하', '찬송하', '찬양하', '가상하'],
#  '잠': ['잠', '수면', '숙면'],
#  '선잠': ['선잠', '낮잠', '수면'],
#  '박수갈채하': ['박수갈채하'],
#  '강습하': ['강습하', '공격하'],
#  '연발하': ['연발하'],
#  '오한': ['오한', '떨', '전율'],
#  '울음보': ['울음보', '울음', '오열'],
#  '오열': ['오열'],
#  '애곡': ['애곡', '애호', '곡', '통곡'],
#  '산출': ['산출', '셈', '산정', '계수', '추산', '계산', '타산', '산수'],
#  '경고하': ['경고하', '주의하'],
#  '나누기': ['나누기'],
#  '으름장놓': ['으름장놓', '공갈치', '위협하'],
#  '적산': ['적산'],
#  '상승': ['상승'],
#  '공제': ['공제', '마이너스', '감산'],
#  '상가': ['상가', '가산', '가계', '합산', '적산'],
#  '진언하': ['진언하', '상담하', '조언하'],
#  '해석': ['해석'],
#  '공고하': ['공고하', '고지하', '통고하', '안내하'],
#  '부르': ['부르'],
#  '심판': ['심판', '판단', '재단', '판가름', '단정', '재판', '감별'],
#  '채점': ['채점', '평가'],
#  '권유하': ['권유하', '권하', '권장하'],
#  '판단': ['판단'],
#  '조언하': ['조언하'],
#  '지각': ['지각'],
#  '자문하': ['자문하'],
#  '일별': ['일별', '일견'],
#  '진술하': ['진술하'],
#  '복종하': ['복종하'],
#  '주시': ['주시', '보', '응시'],
#  '응시': ['응시'],
#  '구경': ['구경'],
#  '관찰': ['관찰', '주목'],
#  '보': ['보', '경계', '감시'],
#  '청각': ['청각', '청취', '듣기', '청문', '방청'],
#  '가상하': ['가상하', '칭찬하'],
#  '후각': ['후각'],
#  '수업': ['수업'],
#  '공언하': ['공언하'],
#  '체결하': ['체결하', '약정하', '계약하'],
#  '장담하': ['장담하', '확보하'],
#  '보증하': ['보증하', '장담하', '확보하'],
#  '오리엔테이션': ['오리엔테이션'],
#  '사례하': ['사례하', '감사하'],
#  '사과하': ['사과하', '사죄하'],
#  '변명하': ['변명하', '핑계대'],
#  '트레이닝': ['트레이닝', '레슨', '연마', '체험', '훈련', '수련', '운동', '연습', '실천'],
#  '조련': ['조련'],
#  '리허설': ['리허설', '예행연습'],
#  '인사하': ['인사하'],
#  '복습': ['복습'],
#  '연습': ['연습'],
#  '경례하': ['경례하'],
#  '호소하': ['호소하'],
#  '소개하': ['소개하'],
#  '선고하': ['선고하'],
#  '촬영': ['촬영'],
#  '함양하': ['함양하', '양육하', '양성하', '육성하', '보육하'],
#  '창작': ['창작', '독창', '창출', '창조', '창안'],
#  '편성': ['편성'],
#  '녹음': ['녹음', '수록'],
#  '부설': ['부설', '건립', '신축', '건설', '조성', '가설', '구축', '건축', '축조'],
#  '건립': ['건립', '건축', '가설'],
#  '구축': ['구축'],
#  '해체': ['해체', '분해'],
#  '양산': ['양산'],
#  '기능': ['기능'],
#  '재배': ['재배'],
#  '귓속말하': ['귓속말하'],
#  '원예': ['원예'],
#  '식재': ['식재'],
#  '목양': ['목양', '목축'],
#  '수확기': ['수확기'],
#  '발굴': ['발굴', '채굴', '광업'],
#  '산업': ['산업', '사업'],
#  '행세하': ['행세하', '가리키'],
#  '제조업': ['제조업',
#   '산출',
#   '조제',
#   '공업',
#   '제조',
#   '생산',
#   '위조',
#   '조작',
#   '조성',
#   '조립',
#   '산업',
#   '제작',
#   '가공'],
#  '조성': ['조성', '성형', '편성'],
#  '단조': ['단조'],
#  '조립': ['조립'],
#  '공': ['공'],
#  '시사하': ['시사하'],
#  '고안': ['고안', '디자인'],
#  '모사': ['모사'],
#  '분대': ['분대'],
#  '작곡': ['작곡', '저술', '글짓기', '편성', '작가', '저작'],
#  '각색': ['각색'],
#  '글짓기': ['글짓기'],
#  '의미하': ['의미하'],
#  '기백': ['기백'],
#  '공예': ['공예'],
#  '그림': ['그림'],
#  '말씀하': ['말씀하', '이야기하', '상담하'],
#  '조각': ['조각', '새김질'],
#  '조소': ['조소'],
#  '발명': ['발명', '고안'],
#  '천공': ['천공'],
#  '찾': ['찾', '검색', '수사', '탐색', '수색'],
#  '탐색': ['탐색'],
#  '열거하': ['열거하'],
#  '물색': ['물색'],
#  '탐방': ['탐방', '수사', '탐색', '수색'],
#  '설정하': ['설정하', '결정하', '확정하', '지정하', '정의하'],
#  '지명하': ['지명하'],
#  '움직임': ['움직임'],
#  '발음하': ['발음하'],
#  '국지전': ['국지전'],
#  '심리전': ['심리전'],
#  '정당방위': ['정당방위'],
#  '정의하': ['정의하'],
#  '전투': ['전투'],
#  '민방위': ['민방위'],
#  '내란': ['내란'],
#  '침략': ['침략'],
#  '전란': ['전란', '교전', '전쟁'],
#  '신고하': ['신고하'],
#  '출판하': ['출판하'],
#  '편집하': ['편집하'],
#  '캠페인': ['캠페인'],
#  '방영하': ['방영하'],
#  '전교': ['전교'],
#  '재단하': ['재단하', '판정하'],
#  '진격': ['진격', '습격', '공격', '진공'],
#  '방송하': ['방송하'],
#  '싸움': ['싸움', '전화', '간과', '전쟁', '전투', '교전', '사려'],
#  '중계하': ['중계하'],
#  '폭격': ['폭격', '공습'],
#  '돌격': ['돌격'],
#  '역습': ['역습', '반격'],
#  '습격': ['습격', '급습'],
#  '침범': ['침범', '침입', '침략', '공략', '잠식', '침공', '입구', '침구'],
#  '강습': ['강습', '습격', '급습'],
#  '반공': ['반공', '반격', '역습'],
#  '전언하': ['전언하', '표현하'],
#  '탄식하': ['탄식하'],
#  '상징하': ['상징하'],
#  '연설하': ['연설하'],
#  '게시하': ['게시하'],
#  '활동하': ['활동하'],
#  '포격': ['포격'],
#  '세균전': ['세균전'],
#  '사인하': ['사인하', '서명하'],
#  '기록하': ['기록하'],
#  '등록하': ['등록하', '등기하', '기록하'],
#  '차지': ['차지', '가지'],
#  '측량': ['측량'],
#  '배열': ['배열', '열차'],
#  '언명하': ['언명하', '확언하'],
#  '긍정하': ['긍정하', '시인하'],
#  '증언하': ['증언하'],
#  '지연': ['지연', '연장'],
#  '되풀이': ['되풀이', '중복', '반복', '재연'],
#  '반복': ['반복', '되풀이'],
#  '중복': ['중복'],
#  '단언하': ['단언하'],
#  '언급하': ['언급하'],
#  '재연': ['재연'],
#  '남': ['남'],
#  '정기': ['정기'],
#  '식전': ['식전', '의식'],
#  '사설하': ['사설하'],
#  '제의': ['제의'],
#  '할례': ['할례'],
#  '예배': ['예배', '용역', '활동'],
#  '양보하': ['양보하', '타협하'],
#  '출가': ['출가', '혼례', '혼인', '관혼상제', '웨딩', '결혼식', '결혼'],
#  '세례': ['세례'],
#  '사회화하': ['사회화하', '대화하', '환담하'],
#  '참회': ['참회', '자백', '고백'],
#  '축성': ['축성'],
#  '묵과하': ['묵과하', '침묵하'],
#  '기도': ['기도', '축수'],
#  '치성': ['치성'],
#  '잔말하': ['잔말하'],
#  '비방하': ['비방하'],
#  '신음하': ['신음하'],
#  '나무하': ['나무하'],
#  '숨기': ['숨기', '은닉', '잠복', '은폐'],
#  '복면': ['복면'],
#  '덮': ['덮', '주행', '은폐'],
#  '매몰': ['매몰', '매장'],
#  '중첩': ['중첩'],
#  '주차': ['주차', '주재', '체류', '체재'],
#  '숙박': ['숙박'],
#  '서식': ['서식', '거주'],
#  '동서': ['동서', '동거'],
#  '캠핑': ['캠핑'],
#  '체류': ['체류'],
#  '방문': ['방문'],
#  '내방': ['내방', '내림', '방문'],
#  '공급': ['공급'],
#  '간행': ['간행', '공급', '발행', '공간', '발간'],
#  '주문': ['주문', '청구', '신청', '요구'],
#  '표명하': ['표명하', '말하', '표현하', '표시하', '표출하'],
#  '청구': ['청구', '클레임', '요구'],
#  '휴식': ['휴식'],
#  '주저': ['주저'],
#  '휴양': ['휴양', '휴식', '정양'],
#  '연기': ['연기'],
#  '연회': ['연회', '연기'],
#  '폐회': ['폐회'],
#  '통보하': ['통보하'],
#  '다투': ['다투', '경합하', '경기하', '대항하'],
#  '웃음': ['웃음'],
#  '경기하': ['경기하'],
#  '장해': ['장해', '방해', '장애', '지장', '훼방', '저해'],
#  '폐쇄': ['폐쇄', '내장'],
#  '포위': ['포위'],
#  '중지': ['중지', '정지', '저지', '휴지', '스톱'],
#  '매듭': ['매듭'],
#  '금지': ['금지'],
#  '방지': ['방지'],
#  '연합': ['연합', '연맹', '동맹', '리그'],
#  '친목': ['친목', '상종'],
#  '입회': ['입회', '가입', '가맹'],
#  '배포': ['배포', '반포', '분배', '할당', '배분', '배부', '배급'],
#  '분배': ['분배'],
#  '할부': ['할부', '분담', '분부', '분배', '할당', '배분', '배부', '배당', '배정'],
#  '배분': ['배분', '배급', '할당'],
#  '배당': ['배당', '배분', '분담', '할당'],
#  '경합하': ['경합하'],
#  '기부행위': ['기부행위'],
#  '구호': ['구호'],
#  '트레이드': ['트레이드', '무역', '통상', '교역', '상업'],
#  '자유무역': ['자유무역'],
#  '교전하': ['교전하', '전투하', '전쟁하'],
#  '융통': ['융통'],
#  '근무하': ['근무하'],
#  '경제활동': ['경제활동'],
#  '입대하': ['입대하'],
#  '장': ['장', '시장'],
#  '노동시장': ['노동시장'],
#  '올리': ['올리'],
#  '투입': ['투입', '출자', '투자'],
#  '떨어지': ['떨어지'],
#  '쟁취하': ['쟁취하', '이기', '승리하', '제패하'],
#  '상사': ['상사'],
#  '승리하': ['승리하', '승전하'],
#  '투서': ['투서', '기고'],
#  '교역': ['교역'],
#  '법률행위': ['법률행위'],
#  '업무': ['업무', '사무'],
#  '이전': ['이전', '양도', '양여'],
#  '극복하': ['극복하'],
#  '수도': ['수도', '수수'],
#  '탈환하': ['탈환하'],
#  '상업': ['상업', '흥정', '마케팅', '판매', '시판', '매매', '매각'],
#  '무역': ['무역'],
#  '정복하': ['정복하'],
#  '전매': ['전매', '소매'],
#  '도매': ['도매'],
#  '판매': ['판매', '팔', '매각'],
#  '항복하': ['항복하', '투항하'],
#  '덤핑': ['덤핑', '투매', '투기'],
#  '행상': ['행상', '판매', '매각'],
#  '세일': ['세일', '매각', '발매', '매매', '판매'],
#  '공격하': ['공격하', '습격하'],
#  '급습하': ['급습하', '돌격하'],
#  '일': ['일'],
#  '납부': ['납부', '납입', '반제', '지출', '지불', '내'],
#  '선불': ['선불'],
#  '반제': ['반제'],
#  '진격하': ['진격하', '습격하', '돌격하'],
#  '지출': ['지출'],
#  '국정': ['국정', '통치', '관리', '지배', '경륜'],
#  '침범하': ['침범하', '침략하', '침입하', '침공하'],
#  '제정': ['제정'],
#  '방어하': ['방어하', '방위하', '수비하'],
#  '보호하': ['보호하'],
#  '지배': ['지배'],
#  '경호하': ['경호하', '보호하', '수호하', '수비하', '호위하', '방위하', '방비하', '경위하'],
#  '보육': ['보육', '양육', '함양', '수양', '육성', '양성', '훈육'],
#  '직책': ['직책', '부담', '책임', '직분', '채무', '책', '짐', '책무', '의무'],
#  '효행': ['효행'],
#  '저지하': ['저지하', '저해하'],
#  '명가': ['명가', '가호'],
#  '지휘': ['지휘'],
#  '발사하': ['발사하'],
#  '처우': ['처우', '대우'],
#  '감독': ['감독', '총리', '통할', '단속', '감리', '주관', '통감', '지배', '주재', '관리'],
#  '총격하': ['총격하', '발포하', '발사하', '사격하'],
#  '방비하': ['방비하', '보호하', '수호하', '방어하', '방위하', '옹호하'],
#  '통관': ['통관', '허가'],
#  '특사': ['특사'],
#  '사냥하': ['사냥하'],
#  '마련': ['마련', '채비', '준비', '대비', '하', '예비', '복선'],
#  '예산': ['예산', '계획', '기획', '배포', '도모'],
#  '계획': ['계획', '과정'],
#  '진력하': ['진력하'],
#  '진정': ['진정'],
#  '복수하': ['복수하', '설욕하', '보복하'],
#  '차별': ['차별', '사'],
#  '소비하': ['소비하', '소모하'],
#  '허비하': ['허비하', '탕진하', '소모하', '낭비하'],
#  '처형': ['처형', '형', '징벌', '천벌', '형벌', '죄과', '죄', '제재', '벌', '징계', '벌금', '처벌'],
#  '징벌': ['징벌', '제재', '질책'],
#  '체벌': ['체벌', '체형'],
#  '오용하': ['오용하', '남용하', '악용하'],
#  ...}

# %% [markdown]
# ## Method

# %%
sentence = "제가 우울감을 느낀지는 오래됐는데 점점 개선되고 있다고 느껴요"

# %%
def get_only_hangul(sentence):
    return ' '.join(re.findall(r'[\uac00-\ud7a3]+', sentence))

# %% [markdown]
# ### SR(synonym replacement)

# %%
def get_synonyms(word: str) -> list:
    # 동의어 목록을 반환하거나 빈 리스트 반환
    return wordnet.get(word, [])

def synonym_replacement(words: list, n: int) -> list:
    new_words = words.copy()
    random.shuffle(new_words) # 단어 목록을 무작위로 섞음
    num_replaced = 0
    
    for idx in range(len(new_words)):
        synonyms = get_synonyms(new_words[idx])
        if synonyms: # 동의어가 있는 경우
            synonym = random.choice(synonyms) # 무작위 동의어 선택
            new_words[idx] = synonym # 단어 교체
            num_replaced += 1
        if num_replaced >= n: # 교체할 단어 수에 도달한 경우 반복 종료
            break
        
    return new_words

n = 5
print(synonym_replacement(sentence.split(), n))
# Out:
# ['느낀지는', '제가', '우울감을', '개선되고', '점점', '느껴요', '있다고', '오래됐는데']

# %% [markdown]
# ### RD(random deletion)

# %%
def random_deletion(words: list, p: float) -> list:
    # 리스트에 단어가 하나만 있으면 그대로 반환
    if len(words) == 1:
        return words
    
    new_words = [word for word in words if random.random() > p] # 확률 p보다 큰 경우에만 단어 유지
    
    # 모든 단어가 삭제된 경우 하나의 단어를 임의로 선택하여 반환
    return new_words if new_words else [random.choice(words)]

# 예제 실행
p = 0.3 
print(random_deletion(sentence.split(), p))
# Out:
# ['제가', '오래됐는데', '점점', '개선되고', '느껴요']

# %% [markdown]
# ### RS(random swap)

# %%
def random_swap(words: list, n: int) -> list:
    new_words = words.copy()
    length = len(new_words)
    for _ in range(n):
        if length > 1: # 최소 2개의 단어가 있는지 확인
            random_idx_1 = random.randint(0, length - 1)
            random_idx_2 = random_idx_1
            while random_idx_2 == random_idx_1:
                random_idx_2 = random.randint(0, length - 1)
            new_words[random_idx_1], new_words[random_idx_2] = new_words[random_idx_2], new_words[random_idx_1]
            
    return new_words

# Example usage:
n = 3 # Number of swaps
print(random_swap(sentence.split(), n))
# Out:
# ['개선되고', '우울감을', '점점', '느낀지는', '오래됐는데', '제가', '있다고', '느껴요']

# %% [markdown]
# ### RI(random insertion)

# %%
def random_insertion(words: list, n: int, get_synonyms: get_synonyms) -> list:
    new_words = words.copy()
    length = len(new_words)
    
    for _ in range(n):
        if length == 0: # 동의어가 없으면 무시
            break
        
        # 무작위 선택
        random_word = new_words[random.randint(0, length - 1)]
        synonyms = get_synonyms(random_word)
        
        if synonyms:
            random_synonym = random.choice(synonyms)
            random_idx = random.randint(0, length)
            new_words.insert(random_idx, random_synonym)
            length += 1 
            
    return new_words

n = 3
print(random_insertion(sentence.split(), n, get_synonyms))
# Out:
# ['제가', '우울감을', '느낀지는', '오래됐는데', '점점', '개선되고', '있다고', '느껴요']

# %% [markdown]
# ## EDA

# %%
def EDA(sentence: str, alpha_sr: float=0.1, alpha_ri: float=0.1, alpha_rs: float=0.1,
        p_rd: float=0.1, num_aug: int=9) -> list:
    sentence = get_only_hangul(sentence)
    words = sentence.split()
    num_words = len(words)
    num_new_per_technique = int(num_aug / 4) + 1
    
    # Calculate number of words to modify based on the length of the sentence
    n_sr = max(1, int(alpha_sr * num_words))
    n_ri = max(1, int(alpha_ri * num_words))
    n_rs = max(1, int(alpha_rs * num_words))
    
    augmented_sentences = []
    
    # Perform each augmentation technique
    for _ in range(num_new_per_technique):
        augmented_sentences.append(' '.join(synonym_replacement(words, n_sr)))
        augmented_sentences.append(' '.join(random_insertion(words, n_ri, get_synonyms)))
        augmented_sentences.append(' '.join(random_swap(words, n_rs)))
        augmented_sentences.append(' '.join(random_deletion(words, p_rd)))
        
    # print(augmented_sentences)
    # Ensure only valid Hangul remains, shuffle, and trim to the desired number of augmented sentences
    augmented_sentences = [get_only_hangul(s) for s in augmented_sentences if s.strip()]
    random.shuffle(augmented_sentences)
    augmented_sentences = augmented_sentences[:num_aug]
    
    # Always include the original sentence
    augmented_sentences.append(sentence)
    
    return augmented_sentences

# %%
tmp = EDA(sentence)

tmp
# Out:
# ['우울감을 있다고 느낀지는 제가 느껴요 개선되고 점점 오래됐는데',
#  '제가 우울감을 느낀지는 오래됐는데 개선되고 있다고 느껴요',
#  '제가 우울감을 느낀지는 오래됐는데 점점 개선되고 있다고 느껴요',
#  '제가 우울감을 느낀지는 점점 오래됐는데 개선되고 있다고 느껴요',
#  '제가 우울감을 느낀지는 오래됐는데 점점 개선되고 있다고 느껴요',
#  '제가 우울감을 느낀지는 오래됐는데 개선되고 점점 있다고 느껴요',
#  '개선되고 느껴요 우울감을 제가 점점 느낀지는 있다고 오래됐는데',
#  '제가 우울감을 느낀지는 오래됐는데 점점 개선되고 있다고 느껴요',
#  '우울감을 제가 오래됐는데 있다고 느낀지는 개선되고 점점 느껴요',
#  '제가 우울감을 느낀지는 오래됐는데 점점 개선되고 있다고 느껴요']

# %% [markdown]
# # Sentence Transformers

# %% [markdown]
# 한국어 sentence transformers 모델을 가져와 학습을 시킨 후, 데이터를 증강하는 방법 추천

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np
from sentence_transformers import SentenceTransformer, util
import numpy as np

embedder = SentenceTransformer("jhgan/ko-sroberta-multitask")

# Corpus with example sentences
corpus = ['한 남자가 음식을 먹는다.',
 '한 남자가 빵 한 조각을 먹는다.',
 '그 여자가 아이를 돌본다.',
 '한 남자가 말을 탄다.',
 '한 여자가 바이올린을 연주한다.',
 '두 남자가 수레를 숲 속으로 밀었다.',
 '한 남자가 담으로 싸인 땅에서 백마를 타고 있다.',
 '원숭이 한 마리가 드럼을 연주한다.',
 '치타 한 마리가 먹이 뒤에서 달리고 있다.']

corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# Query sentences:
queries = ['한 남자가 파스타를 먹는다.',
  '고릴라 의상을 입은 누군가가 드럼을 연주하고 있다.',
  '치타가 들판을 가로 질러 먹이를 쫓는다.']

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = 5
for query in queries:
 query_embedding = embedder.encode(query, convert_to_tensor=True)
 cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
 cos_scores = cos_scores.cpu()

 #We use np.argpartition, to only partially sort the top_k results
 top_results = np.argpartition(-cos_scores, range(top_k))[0:top_k]

 print("\n\n======================\n\n")
 print("Query:", query)
 print("\nTop 5 most similar sentences in corpus:")

 for idx in top_results[0:top_k]:
  print(corpus[idx].strip(), "(Score: %.4f)" % (cos_scores[idx]))
embedder = SentenceTransformer()
# Out:
# ======================
#
#
# Query: 한 남자가 파스타를 먹는다.
#
# Top 5 most similar sentences in corpus:
# 한 남자가 음식을 먹는다. (Score: 0.5742)
# 한 남자가 빵 한 조각을 먹는다. (Score: 0.4833)
# 한 남자가 말을 탄다. (Score: 0.1337)
# 치타 한 마리가 먹이 뒤에서 달리고 있다. (Score: 0.1249)
# 한 남자가 담으로 싸인 땅에서 백마를 타고 있다. (Score: 0.1028)
#
#
# ======================
#
#
# Query: 고릴라 의상을 입은 누군가가 드럼을 연주하고 있다.
#
# Top 5 most similar sentences in corpus:
# 원숭이 한 마리가 드럼을 연주한다. (Score: 0.6619)
# 한 여자가 바이올린을 연주한다. (Score: 0.2921)
# 치타 한 마리가 먹이 뒤에서 달리고 있다. (Score: 0.2271)
# 한 남자가 담으로 싸인 땅에서 백마를 타고 있다. (Score: 0.1968)
# 한 남자가 음식을 먹는다. (Score: 0.1248)
#
#
# ======================
#
#
# Query: 치타가 들판을 가로 질러 먹이를 쫓는다.
#
# Top 5 most similar sentences in corpus:
# 치타 한 마리가 먹이 뒤에서 달리고 있다. (Score: 0.7968)
# 원숭이 한 마리가 드럼을 연주한다. (Score: 0.2194)
# 한 남자가 담으로 싸인 땅에서 백마를 타고 있다. (Score: 0.1424)
# 한 남자가 음식을 먹는다. (Score: 0.1308)
# 한 남자가 빵 한 조각을 먹는다. (Score: 0.0911)

# %%
import pandas as pd

df = pd.read_csv('./data/train.csv')

df
# Out:
#             id                          질문_1  \
# 0    TRAIN_000                     면진장치가 뭐야?
# 1    TRAIN_001                내진설계의 종류 좀 알려줘
# 2    TRAIN_002                 철골구조의 장점이 뭐야?
# 3    TRAIN_003             철골철근 콘크리트 구조가 뭐야?
# 4    TRAIN_004              철골구조는 어떤 방식이 있어?
# ..         ...                           ...
# 639  TRAIN_639             벽장 부위 결로의 원인이 뭐야?
# 640  TRAIN_640     AD, PD에 면한 벽체 결로의 원인이 뭐야?
# 641  TRAIN_641   외벽 모서리 부위에 결로가 발생하는 원인이 뭐야?
# 642  TRAIN_642                창호 결로의 대책은 뭐야?
# 643  TRAIN_643  AD, PD에 면한 벽체 결로에 대한 대책은 뭐야?
#
#                                       질문_2 category  \
# 0                 면진장치에 사용되는 주요 기술은 무엇인가요?     건축구조
# 1        내진설계에는 어떤 종류가 있는지 자세히 알려주실 수 있나요?     건축구조
# 2                           철골구조의 장점을 알려줘?     건축구조
# 3         철골철근 콘크리트 구조의 장점과 단점에는 무엇이 있을까요?     건축구조
# 4                     철골구조의 다양한 방식이 무엇인가요?     건축구조
# ..                                     ...      ...
# 639           벽장 부위 결로가 발생하는 주된 원인은 무엇일까요?   타 마감하자
# 640       벽체 결로가 AD나 PD에 면한다면 그 원인이 무엇인가요?   타 마감하자
# 641  외벽 모서리 부위에 결로가 발생하는 것을 예방하는 방법이 있을까요?   타 마감하자
# 642      창호 결로를 해결하기 위한 가장 효과적인 방법은 무엇인가요?   타 마감하자
# 643    AD, PD에 면한 벽체 결로에 대한 대책은 어떤 것이 있나요?   타 마감하자
#
#                                                   답변_1  \
# 0    면진장치란 지반에서 오는 진동 에너지를 흡수하여 건물에 주는 진동을 줄여주는 진동 ...
# 1                   내진 설계의 종류로 내진구조, 제진구조, 면진구조가 있습니다.
# 2    철골구조는 건물의 외벽에는 그다지 하중이 걸리지 않기 때문에 고층 건물의 건축이 가...
# 3    철근철골콘크리트는 철골과 철근, 그리고 콘크리트를 함께 사용하는 건축 구조입니다. ...
# 4                          철골구조는 일반철골구조와 경량철골구조가 있습니다.
# ..                                                 ...
# 639  벽장 부위 결로의 원인은 난방이 이웃한 방과동일한 조건이 되나 그 방에 비해 저온인...
# 640  AD, PD에 면한 벽체 결로의 원인은 외기에 접하는 면 좌, 우측 벽체에는 단열재...
# 641  외벽모서리 부위에 결로가 발생하는 원인은 높은 온도차 때문입니다. 외벽 모서리의 경...
# 642  창호결로의 대책은 제품을 선정할 때 KS에 규정된 프레임을 선정하고 유리의 열관류율...
# 643  AD, PD에 면한 벽체 결로에 대한 대책은 단열재를 미실하게 시공하여 결로가 생기...
#
#                                                   답변_2  \
# 0    면진장치란 건물의 지반에서 발생하는 진동 에너지를 흡수하여 건물을 보호하고, 진동을...
# 1    내진설계에는 내진구조, 제진구조, 면진구조가 있습니다. 내진구조는 건물 구조물이 지...
# 2    철골구조의 장점은 건물의 외벽에는 그다지 하중이 걸리지 않기 때문에 고층 건물의 건...
# 3    철골철근콘크리트 구조는 건축물을 지탱하는 주요 구조물인 철골과 철근, 그리고 콘크리...
# 4    철골구조는 일반철골구조와 경량철골구조가 있습니다. 일반철골구조는 주로 대형 건물이나...
# ..                                                 ...
# 639  벽장 부위 결로의 원인은 주로 난방이 자리잡은 방이 내부 온도가 낮은 반면, 외부 ...
# 640  AD, PD에 면한 벽체 결로의 원인은 외기에 접하는 면 좌, 우측 벽체에는 단열재...
# 641  외벽 모서리 부위에 결로가 발생하는 원인은 중요한 역할을 합니다. 외부에 비치는 세...
# 642  창호 결로의 대책은 KS에 규정된 프레임을 선정하고 유리의 열관류율 및 결로 발생 ...
# 643  AD, PD에 면한 벽체 결로에 대한 대책은 단열재를 미실하게 시공하여 결로가 생기...
#
#                                                   답변_3  \
# 0    면진장치란 지반으로부터 발생하는 진동 에너지를 흡수하여 건물에 전달되는 진동을 줄여...
# 1    내진설계에는 주로 내진구조, 제진구조, 면진구조의 세 가지 종류가 있습니다. 이들은...
# 2    철골구조의 장점은 건물의 외벽에 하중이 적게 걸리기 때문에 고층 건물의 건축이 용이...
# 3    철골철근 콘크리트 구조는 건축물을 지탱하기 위한 구조물에서 일반적으로 사용되는 방식...
# 4    철골구조는 주로 일반철골구조와 경량철골구조로 나뉘어집니다. 이들은 건축 시스템에 따...
# ..                                                 ...
# 639  벽장 부위 결로가 발생하는 원인은 난방이 잘 이루어지지 않아 해당 공간이 저온인 반...
# 640  AD, PD에 면한 벽체 결로의 주된 원인은 외기에 접하는 면 좌, 우측 벽체에 단...
# 641  외벽 모서리 부위에 결로가 발생하는 원인으로는 높은 온도차가 대표적입니다. 외벽 모...
# 642  창호 결로를 예방하기 위한 대책은 KS에 규정된 프레임을 선택하고, 열관류율이 적은...
# 643  AD, PD에 면한 벽체 결로에 대한 대책은 단열재를 미실하게 시공하여 결로가 생기...
#
#                                                   답변_4  \
# 0    면진장치는 건물의 지반으로부터 오는 진동 에너지를 흡수하여 건물에 전달되는 진동을 ...
# 1    내진설계에는 주로 내진구조, 제진구조, 면진구조가 사용됩니다. 내진구조는 건물 구조...
# 2    철골구조의 장점은 건물의 외벽이 하중이 걸리지 않아 공간 활용이 용이하고, 고층 건...
# 3    철골철근콘크리트 구조는 철골과 철근, 그리고 콘크리트를 함께 사용하여 만들어지는 건...
# 4    철골구조는 주로 일반철골구조와 경량철골구조로 구분됩니다. 이외에도 최근에는 고층 건...
# ..                                                 ...
# 639  벽장 부위 결로가 발생하는 원인은 난방이 인접한 방과 같은 조건을 갖추고 있지만, ...
# 640  AD, PD에 면한 벽체 결로의 원인으로는 외기에 접하는 면 좌, 우측 벽체는 일반...
# 641  외벽 모서리 부위에 결로가 발생하는 원인은 실내와 외부의 온도차 때문입니다. 외벽 ...
# 642  창호 결로의 대책은 여러 가지가 있습니다. 먼저, 창호를 선택할 때 KS에 규정된 ...
# 643  AD, PD에 면한 벽체 결로에 대한 대책은 단열재를 미실하게 시공하여 결로가 생기...
#
#                                                   답변_5
# 0    면진장치는 건물에 오는 지반 진동의 영향을 최대한으로 흡수하여 건물에 전달되는 진동...
# 1    내진 설계에는 다양한 종류가 있지만, 대표적으로 내진구조, 제진구조, 면진구조가 있...
# 2    철골구조의 장점은 건물의 외벽에 하중이 크게 걸리지 않아 고층 건물을 건축할 수 있...
# 3    철골철근 콘크리트 구조는 강철 골조와 강철 철근, 그리고 콘크리트를 함께 사용하여 ...
# 4    철골구조는 일반철골구조와 경량철골구조 두 가지 방식이 주로 사용됩니다. 일반철골구조...
# ..                                                 ...
# 639  벽장 부위 결로의 주된 원인은 충분한 환기가 이루어지지 않는 환경과 과도한 습기가 ...
# 640  AD, PD에 면한 벽체 결로의 원인으로는 외부 공기에 노출된 벽면이 실내보다 냉각...
# 641  외벽 모서리 부위에 결로가 발생하는 주요 원인은 높은 온도차입니다. 외벽 모서리는 ...
# 642  창호 결로를 방지하기 위한 대책으로는 KS에 규정된 프레임을 사용하고, 열관류율 및...
# 643  AD, PD에 면한 벽체의 결로에 대한 대책으로는 단열재를 미실하게 시공하여 결로가...
#
# [644 rows x 9 columns]

# %%
values_list = []
for column in ['질문_1', '질문_2', '답변_1', '답변_2', '답변_3', '답변_4', '답변_5']:
    values_list.extend(df[column].tolist())

len(values_list), values_list[:20]
# Out:
# (4508,
#  ['면진장치가 뭐야?',
#   '내진설계의 종류 좀 알려줘',
#   '철골구조의 장점이 뭐야?',
#   '철골철근 콘크리트 구조가 뭐야?',
#   '철골구조는 어떤 방식이 있어?',
#   '커튼월이 뭐야?',
#   '내진구조가 뭐야?',
#   '중목구조 방식이 뭐야?',
#   '기둥-보 구조 방식이 뭐야?',
#   '블록구조가 뭐야',
#   '철골구조의 단점이 뭐야?',
#   '콘크리트 구조는 어떤 방식이 있어?',
#   '철골콘크리트 구조가 뭐야?',
#   '면진구조가 뭐야?',
#   '철골구조가 뭐야?',
#   '면진구조와 제진구조의 차이점이 뭐야?',
#   '철근콘크리트 구조가 뭐야?',
#   '건축물의 구조는 어떻게 구분해?',
#   '조적식 구조는 어떤 방식이 있어?',
#   '목구조는 어떤 방식이 있어?'])

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np
from sentence_transformers import SentenceTransformer, util
import numpy as np

embedder = SentenceTransformer("jhgan/ko-sroberta-multitask")

corpus_embeddings = embedder.encode(values_list, convert_to_tensor=True)

# Query sentences:
queries = ['토목구조는 어떤 방식이 있어?',
  '블록구조의 단점이 뭔가요?',
  '내진설계의 장점으로는 뭐가 있을까요?',
  '면진장치가 뭐야?']

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = 5
for query in queries:
 query_embedding = embedder.encode(query, convert_to_tensor=True)
 cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
 cos_scores = cos_scores.cpu()

 #We use np.argpartition, to only partially sort the top_k results
 top_results = np.argpartition(-cos_scores, range(top_k))[0:top_k]

 print("\n\n======================\n\n")
 print("Query:", query)
 print("\nTop 5 most similar sentences in corpus:")

 for idx in top_results[0:top_k]:
  print(values_list[idx].strip(), "(Score: %.4f)" % (cos_scores[idx]))
embedder = SentenceTransformer()
# Out:
# ======================
#
#
# Query: 토목구조는 어떤 방식이 있어?
#
# Top 5 most similar sentences in corpus:
# 토목이란 무엇인가요? (Score: 0.8570)
# 토목이 뭐야? (Score: 0.8440)
# 콘크리트 구조는 어떤 방식이 있어? (Score: 0.7799)
# 방수공사 공법의 종류는 뭐가 있어? (Score: 0.7405)
# 토목이란 목재, 철재, 토석 등을 써서 도로, 교량, 항만, 제방, 철도, 건물, 상하수도 등을 건설하는 공사를 의미합니다. (Score: 0.7328)
#
#
# ======================
#
#
# Query: 블록구조의 단점이 뭔가요?
#
# Top 5 most similar sentences in corpus:
# 철골구조의 단점이 뭐야? (Score: 0.7763)
# 노출콘크리트의 단점은 무엇인가요? (Score: 0.7297)
# 노출콘크리트의 단점이 뭐야? (Score: 0.7229)
# 큐블럭의 단점이 뭐야? (Score: 0.7072)
# 블록구조가 뭐야 (Score: 0.6926)
#
#
# ======================
#
#
# Query: 내진설계의 장점으로는 뭐가 있을까요?
#
# Top 5 most similar sentences in corpus:
# 내진설계에는 어떤 종류가 있는지 자세히 알려주실 수 있나요? (Score: 0.7864)
# 내진설계의 종류 좀 알려줘 (Score: 0.7460)
# 내진설계에서 안전성을 높이기 위한 순서는 무엇인가요? (Score: 0.7210)
# 내진 설계의 종류로 내진구조, 제진구조, 면진구조가 있습니다. (Score: 0.6974)
# 내진구조가 뭐야? (Score: 0.6928)
#
#
# ======================
#
#
# Query: 면진장치가 뭐야?
#
# Top 5 most similar sentences in corpus:
# 면진장치가 뭐야? (Score: 1.0000)
# 면진장치에 사용되는 주요 기술은 무엇인가요? (Score: 0.8199)
# 못, 또는 기타 이물질로 인해 면 불량이 발생할 수 있어? (Score: 0.6619)
# 면 불량은 뭐야? (Score: 0.6536)
# 면에 이물질이나 손상이 발생할 수 있는 경우가 있다면 어떤 종류의 면을 사용해야 하는 것이 좋을까요? (Score: 0.6476)
